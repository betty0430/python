# %%
#print 三方法
#1.透過區隔要列印變數 print(this,is,a,book)
print("this","is","a","book") #this is a book
a="this"+"is"+"a"+"book"
print(a)            #thisisabook
#2.透過字串的str.format()(新式)
#3.%格式化輸出字符串(舊式)
# Out:
# this is a book
# thisisabook

# %%
#型態轉換
y="1"
print(5*y)
print(5*int(y))
print(5*float(y))
print(5*str(y))
print(5*eval("5*2"))
# Out:
# 11111
# 5
# 5.0
# 11111
# 50

# %%
a=(5*(2+1)**2-3+4/2)
print(a)#()>次方>乘除>加減
# Out:
# 44.0

# %%
a=input("請輸入數字").split(' ')
print(int(a[0])/int(a[1]))#兩數相除
print(int(a[0])//int(a[1]))#求商
print(int(a[0])%int(a[1]))#求餘數
# Out:
# 請輸入數字10 5
# 2.0
# 2
# 0

# %%
a=1
b=1.0
c="c"
print(type(a))#type顯示他為何種別的
print(type(b))
print(type(c))
print(a==b)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# True

# %%
import math
try:
  i=eval(input("求圓面積,請輸入半徑")) #eval() 將字串轉化成數值運算
  print(i*i*math.pi)          #個個數值都可使用
except Exception as a:
  print(a)
finally:
  print("byby");
# Out:
# 求圓面積,請輸入半徑5
# 78.53981633974483
# byby

# %%
x,y,z=1,2,3
x+=1 #x=x+1
y*=2 #y=y*2
z**=3 #z=z^3
print(x,y,z)
# Out:
# 2 4 27

# %%
print("---------------------")
#單行註解
print("---------------------")
'''
多行註解
'''
print("---------------------")
# Out:
# ---------------------
# ---------------------
# ---------------------

# %%
#兩數交換(第三方)
x=int(1)
y=int(10)
print("前")
print("x=",x)# , 結合數字與字串
print("y=",y)
z=x
x=y
y=z
print("後")
print("x=",x)
print("y=",y)
# Out:
# 前
# x= 1
# y= 10
# 後
# x= 10
# y= 1

# %%
#兩數交換(無第三方)
x=int(1)
y=int(10)
x=x+y
y=x-y
x=x-y
print(x,y)
# Out:
# 10 1

# %%
#python變數交換
x=int(1)
y=int(10)
x,y=y,x
print(x,y)
# Out:
# 10 1

# %%
x,y,z=1,10,100
print(x)
