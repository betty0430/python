# %% [markdown]
# #錯誤處理
# try:<br>
# (嘗試下方程式碼)<br>
# except:<br>
# (錯誤情況處理方式)<br>
# else:<br>
# finally:<br>
# (不管錯誤或對，結束時要做的動作)

# %%
#1.
try:
  if(7<x):
    print("good")
except Exception as e:
  print(e)
# Out:
# name 'x' is not defined

# %%
from typing import NamedTuple
#2.
try:
  if(7<x):
    print("good")
except NameError:
  print("名稱錯誤")
except ZeroDivisionError:
  print("/0錯誤")
